# %% [markdown]
# # Harmonic Oscillator and Kepler problem
#
# In a nutshell:
# - There are many flavors of numerical integration. Solvers do not always perform as we would hope - we should be careful.
#
# In this notebook, you will:
# - Write your own solver / integrator
# - Investigate behavior with different parameters
# - Compare to analytic solutions
# - Notice exponential growth of Euler forward error
# - Observe energy conservation or lack thereof
# - Write a better solver and compare
# - Analyze damped harmonic oscillator: consider limiting behavior, compare with analytic
# - Analyze anharmonic oscillator: investigate period vs amplitude
# - Solve for planetary orbit
# - Observe behavior of energies and momenta under integration
#
# For the future? another notebook?:
# - Intro to / comparison with existing integrators in scipy
# - Intro to chaos - 3 body dynamics
# - Investigate reversibility (or irrev) of the solvers
# - Analyze how/when Verlet exactly conserves angular momentum
#
# Resources:
# - A nice discussion of integrators: http://physics.ucsc.edu/~peter/242/leapfrog.pdf
# - More details on higher order symplectic https://en.wikipedia.org/wiki/Symplectic_integrator#A_third-order_example

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Simple Harmonic Oscillator
#
# Let's solve for the motion of a simple "mass on a spring" system.'
# ## $F = -kx$

# %% [markdown]
# ## Euler forward
# We'll begin with the simplest means of stepping forward in time numerically - the Euler forward algorithm.
#
#
# $ F = -k x = m \frac{d^2 x}{dt^2} $
# $\frac{d^2 x}{dt^2} = - \frac{k}{m} x $
#
# Convert this second order ODE into a system of first order ODEs.
#
# $\frac{d x}{dt} = v $
# $\frac{d v}{dt} = - \frac{k}{m} x $
#
# Take the first equation $\frac{d x}{dt} = v $ and write in terms of small differences.
# That is, write out the derivative.
#
# $\frac{x_{t+h} - x_t}{h} = v(t) $
# $x_{t+h} = x_t + v(t) h $
#
# This is a rule for stepping the position variable forward in time by an amount $h$.
#
# Similarly, for $v$ we have
# $v_{t+h} = v_t + a(t) h $
# $v_{t+h} = v_t + a(x_t) h $
# $v_{t+h} = v_t - \frac{k}{m} x_t h $
#
# This is called the "forward Euler" method for integration.

# %%
def SHO_euler_step(x, v, k, m, dt):
    net_force = -k * x
    a = net_force / m
    x += v * dt
    v += a * dt
    return x, v

# %% [markdown]
# ## Analytic solution
#
# In this case, the analytic solution is simple.
#
# $ F = -k x = m \frac{d^2 x}{dt^2} $
# $\frac{d^2 x}{dt^2} = \frac{k}{m} x $
# $ x(t) = A \cos(\omega t + \phi) , \omega = \sqrt{\frac{k}{m}} $

# %%
def SHO_analytic(phase_pt0, k, m, ts):
    """
    Given an initial condition of a SHO, compute the analytic trajectory at times `ts'.
    x(t) = A \cos(\omega t + \phi)
    v(t) = -A \omega \sin(\omega t + \phi)
    where \omega = \sqrt(\frac{k}{m})
    
    x0 = x(0) = A \cos(\phi)
    v0 = v(0) = -A \omega \sin(\phi)
    """
    omega = (k/m)**0.5
    
    x0, v0 = phase_pt0
    
    A = (x0**2 + (v0/omega)**2)**0.5
    
    phi = np.arccos(x0 / A)
    
    xs = A * np.cos(omega * ts + phi)
    vs = -A * omega * np.sin(omega * ts + phi)
    
    return np.column_stack([xs, vs])

# %%
# Define the system.
k = 2.0
m = 7.0

# Choose initial conditions.
x = 3.0
v = 0.0

# Define the simulation.
N = 1000
dt = 0.05

# Prepare lists to collect the simulation data.
xs = [x]
vs = [v]

for step in range(N-1):
    newx, newv = SHO_euler_step(x=xs[step], v=vs[step], k=k, m=m, dt=dt)
    xs.append(newx)
    vs.append(newv)

times = dt*np.arange(N)

# Compute analytic solution for comparison
phase_pts_analytic = SHO_analytic(phase_pt0=[x, v], k=k, m=m, ts=times)

# Plot
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(16, 8))     
ax[0].plot(times, xs, '-', label='dt = {}'.format(dt))
ax[0].plot(times, phase_pts_analytic[:, 0], '-', label='analytic')

#ax[1].plot(times, phase_pts_analytic[:, 0] - xs, '-', label='dt = {}'.format(dt))
ax[1].plot(times, xs, '-', label='dt = {}'.format(dt))

ax[1].hlines(0, times[0], times[-1], 'k')

ax[0].legend()

# Here is a way to plot vertical lines at the times where we expect $x=0$.
omega = np.sqrt(k/m)
period = 2*np.pi / omega

for n in range(int(2*N*dt/period)):
    ax[1].vlines(period * (n/2 + 1/4), -1, 1, 'k', lw=0.5)

# %% [markdown]
# ### TRY:
# What happens to the amplitude of the simulation for modest values of $dt$ like $dt=0.05$?
#
# This is not bad - it gets the basic idea.
# What happens when you integrate for 10 times as many steps?
#
# The angular frequency is known to be $\omega = \sqrt{k/m}$.
#
# In the above plot, mark vertical lines where we expect peaks.
# Does the simulation get the period correct?
#
# Does the error in the period get worse as the amplitude increases?
# Or does each cycle accumulate the same phase shift?
#
# Can you automate estimation of the numerical period?
# Use this method to create a plot of period vs dt.

# %%
# Maybe we need to "crank" up the resolution and use a smaller dt... Let's do it!
# Experiment with different values for dt.

# Choose initial conditions
x = 3.0
v = 0.0
k = 2.0
m = 7.0

fig = plt.figure(figsize=(16, 4))

T = 50
dt0 = 0.05

# Simulate and plot for several values of dt.
for dt in dt0 * 0.5**np.arange(0, 5): # Check your understanding of this line.

    N = int(T/dt)

    xs = [x]
    vs = [v]

    for step in range(N-1):
        newx, newv = SHO_euler_step(x=xs[step], v=vs[step], k=k, m=m, dt=dt)
        xs.append(newx)
        vs.append(newv)

    times = dt*np.arange(N)
    plt.plot(times, xs, '-', label='dt = {}'.format(dt))

plt.legend()

# %% [markdown]
# ### Is this good enough?
#
# The smallest value for dt looks pretty good.
# But what if we want to model an oscillator that is running for $10^3$ periods?

# %%
# Simulate 1000 periods.
N = 10**2 # YOUFILLIN
dt = 0.01

# Choose initial conditions
x = 3.0
v = 0.0
k = 2.0
m = 7.0

fig = plt.figure(figsize=(16, 4))

xs = [x]
vs = [v]

for step in range(N-1):
    newx, newv = SHO_euler_step(x=xs[step], v=vs[step], k=k, m=m, dt=dt)
    xs.append(newx)
    vs.append(newv)

times = dt*np.arange(N)
plt.plot(times, xs, '-', label='dt = {}'.format(dt))

# %%
def SHO_energy(x, v, k, m):
    """
    Total energy of simple harmonic oscillator.
    
    E = KE + PE = \frac{1}{2} m v^2 + \frac{1}{2} k x^2
    """
    return 0.5 * m * v**2 + 0.5 * k * x**2

# %%
# Look at the evolution of energy.

N = 10**5
dt = 0.01

# Choose initial conditions
x = 3.0
v = 0.0
k = 2.0
m = 7.0

fig = plt.figure(figsize=(16, 4))

xs = [x]
vs = [v]

for step in range(N-1):
    newx, newv = SHO_euler_step(x=xs[step], v=vs[step], k=k, m=m, dt=dt)
    xs.append(newx)
    vs.append(newv)

times = dt*np.arange(N)

# Different ways to compute the energies.
# Method 1 - loop over list
energies = []
for ind in range(N):
    energies.append(SHO_energy(xs[ind], vs[ind], k, m))

# Method 2 - list comprehension.
# energies = [SHO_energy(xs[ind], vs[ind], k, m) for ind in range(N)]

# Method 3 - vectorize the function and its input.
# If we convert the input lists to arrays, we can compute in a more "natural" way.
# Look at the SHO_energy function - the operations here all work "correctly" on numpy arrays too.
# TRY: Can you come up with an energy function that will *not correctly generalize to arrays?
# xs = np.array(xs)
# vs = np.array(vs)
# energies = SHO_energy(xs, vs, k, m)

plt.plot(times, energies, '-', label='dt = {}'.format(dt))

# %%
# What happens when we make a small change in the algorithm for stepping forward numerically?
# What exactly is the change in the algorithm?
# What is its local effect?
# What is the broader impact?

# There are many names for this method: backward Euler, implicit Euler, Euler Cromer...
def SHO_euler_step2(x, v, k, m, dt):
    x += v * dt
    net_force = -k * x
    a = net_force / m
    v += a * dt
    return x, v

# %%
# Look at stability of this slightly different integration.

N = 5000*20
dt = 0.01

# Choose initial conditions
x = 3.0
v = 0.0
k = 2.0
m = 7.0

fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(16, 8))

xs = [x]
vs = [v]

for step in range(N-1):
    newx, newv = SHO_euler_step2(x=xs[step], v=vs[step], k=k, m=m, dt=dt)
    xs.append(newx)
    vs.append(newv)

times = dt*np.arange(N)

ax[0].plot(times, xs, '-', label='dt = {}'.format(dt))

xs = np.array(xs)
vs = np.array(vs)
energies = SHO_energy(xs, vs, k, m)

ax[1].plot(times, energies, '-', label='dt = {}'.format(dt))

# %%
# So far we have been using a "stepping method" that combined two distinct ideas.
# We combined the physics (simple harmonic oscillator) with the numerical algorithm (forward, backward, etc).
# From a coding perspective, this is not good.

# Let's do the work to separate these ideas functionally.
# This will have definite advantages, for example making our code more flexible, and easier to test.

def SHO_accel(x, k, m):
    return -k * x / m

def euler_step(phase_pt, accel_func, dt):
    # Euler forward
    a = accel_func(phase_pt)
    phase_pt[0] += phase_pt[1] * dt
    phase_pt[1] += a * dt
    return phase_pt

def euler_step2(phase_pt, accel_func, dt):
    # Euler backward
    phase_pt[0] += phase_pt[1] * dt
    a = accel_func(phase_pt)
    phase_pt[1] += a * dt
    return phase_pt

def integrate(phase_pt0, accel_func, step_func, t0, T, N):
    """Integrate a trajectory. 
    
    Parameters:
    
    accel_func : function that accepts a point in phase space and returns the acceleration.
        This contains the physics.
    
    step_func : numerical method for advancing the phase space point forward. 
        Examples are Euler forward, Euler backward, Verlet etc.
        
    Returns:
    
    phase_pts : array containing trajectory through phase space.
    
    times : times associated with those points in phase space.
    """
    dt = (T - t0)/N
        
    phase_pts = np.zeros((N + 1, 2))
    phase_pts[0, :] = phase_pt0
    
    for ind in range(N):
        phase_pts[ind + 1, :] = step_func(phase_pt=phase_pts[ind], accel_func=accel_func, dt=dt)

    times = dt*np.arange(N + 1)

    return phase_pts, times

# %%
k = 3.0
m = 7.0

phase_pt0 = [3.0, 0.0]
t0 = 0
T = 50

N = 1000

accel_func = lambda phase_pt: SHO_accel(x=phase_pt[0], k=k, m=m)

fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(16, 8))

# Euler forward
phase_pts, times = integrate(phase_pt0=phase_pt0, accel_func=accel_func, step_func=euler_step, t0=t0, T=T, N=N)

ax[0].plot(times, phase_pts[:, 0], '-', label='euler forward')
ax[1].plot(times, SHO_energy(phase_pts[:, 0], phase_pts[:, 1], k, m), label='euler forward')

# Leapfrog(ish)
phase_pts, times = integrate(phase_pt0=phase_pt0, accel_func=accel_func, step_func=euler_step2, t0=t0, T=T, N=N)

ax[0].plot(times, phase_pts[:, 0], '-', label='leapfrog')
ax[1].plot(times, SHO_energy(phase_pts[:, 0], phase_pts[:, 1], k, m), label='leapfrog')

ax[0].hlines(phase_pt0[0], 0, T)
ax[0].hlines(-phase_pt0[0], 0, T)
ax[1].hlines(SHO_energy(phase_pt0[0], phase_pt0[1], k, m), 0, T)

ax[0].legend()
ax[1].legend()

# %%
# The verlet integrator has the power of the leapfrog and also yields synchronous phase points.
# TODO : update this dependent on how we resolve the euler step reference issue.
# Since there is a vhalf here, maybe it doesn't really matter

def velocity_verlet_step(phase_pt, accel_func, dt):
    x, v = phase_pt
    a = accel_func(phase_pt)
    vhalf = v + 0.5 * a * dt
    x1 = x + vhalf * dt
    a = accel_func([x1, v])
    v1 = vhalf + 0.5 * a * dt

    return [x1, v1]

# %%
k = 3.0
m = 7.0

phase_pt0 = [3.0, 0.0]
t0 = 0
T = 50

N = 100

accel_func = lambda phase_pt: SHO_accel(x=phase_pt[0], k=k, m=m)

fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(16, 10))

# # Euler forward
# phase_pts, times = integrate(phase_pt0=phase_pt0, accel_func=accel_func, step_func=euler_step, t0=t0, T=T, N=N)
# ax[0].plot(times, phase_pts[:, 0], '-', label='euler forward')
# ax[1].plot(times, phase_pts[:, 0], '-', label='euler forward')
# ax[2].plot(times, SHO_energy(phase_pts[:, 0], phase_pts[:, 1], k, m), label='euler forward')

# Leapfrog(ish)
phase_pts, times = integrate(phase_pt0=phase_pt0, accel_func=accel_func, step_func=euler_step2, t0=t0, T=T, N=N)
ax[0].plot(times, phase_pts[:, 0], '-', label='leapfrog')
ax[1].plot(times, phase_pts[:, 1], '-', label='leapfrog')
ax[2].plot(times, SHO_energy(phase_pts[:, 0], phase_pts[:, 1], k, m), label='leapfrog')

# Velocity verlet
phase_pts, times = integrate(phase_pt0=phase_pt0, accel_func=accel_func, step_func=velocity_verlet_step, t0=t0, T=T, N=N)
ax[0].plot(times, phase_pts[:, 0], '-', label='verlet')
ax[1].plot(times, phase_pts[:, 1], '-', label='verlet')
ax[2].plot(times, SHO_energy(phase_pts[:, 0], phase_pts[:, 1], k, m), label='verlet')

# Analytic
phase_pts_analytic = SHO_analytic(phase_pt0=[x, v], k=k, m=m, ts=times)
ax[0].plot(times, phase_pts_analytic[:, 0], 'o', markersize=2, label='analytic')
ax[1].plot(times, phase_pts_analytic[:, 1], 'o', markersize=2, label='analytic')
ax[2].plot(times, SHO_energy(phase_pts_analytic[:, 0], phase_pts_analytic[:, 1], k=k, m=m), '-', label='analytic')

ax[0].hlines(phase_pt0[0], 0, T)
ax[0].hlines(-phase_pt0[0], 0, T)
ax[2].hlines(SHO_energy(phase_pt0[0], phase_pt0[1], k, m), 0, T)

ax[0].legend()
ax[1].legend()
ax[2].legend()

# %%
# Accuracy improves with decreasing dt - not surprising.
# TRY: can you imagine some kind of simulation where the accuracy became *worse* as dt became very, very small?

# %% [markdown]
# # Damped Harmonic Oscillator

# %%
# Damped Harmonic Oscillator
def DHO_accel(x, v, k, m, b):
    return (-k * x - b * v) / m
    
def DHO_analytic(phase_pt0, k, m, b, ts):
    
    x0, v0 = phase_pt0
    omega_0 = (k/m)**0.5
    gamma = b / (2*m)
    
    temp = (omega_0**2 - gamma**2)**0.5
    lambda_p = 1j*gamma + temp
    lambda_m = 1j*gamma - temp
    
    A = (v0 - 1j * lambda_m * x0) / (1j * lambda_p - 1j * lambda_m)
    B = x0 - A
    
    xs = A * np.exp(1j*lambda_p * ts) + B * np.exp(1j*lambda_m * ts)
    vs = 1j*lambda_p * A * np.exp(1j*lambda_p * ts) + 1j * lambda_m * B * np.exp(1j*lambda_m * ts)
    
    xs = xs.real # The imaginary components should be ~zero.
    vs = vs.real
    
    return np.column_stack([xs, vs])

# %%
k = 1.0
m = 4.0
b = 0.2

# phase_pt0 = [0.0, 3.0]
phase_pt0 = [3.0, 0.0]
t0 = 0
T = 50

N = 10**3

accel_func = lambda phase_pt: DHO_accel(x=phase_pt[0], v = phase_pt[1], k=k, m=m, b=b)

fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(16, 8))

# # Euler forward
# phase_pts, times = integrate(phase_pt0=phase_pt0, accel_func=accel_func, step_func=euler_step, t0=t0, T=T, N=N)
# ax[0].plot(times, phase_pts[:, 0], '-', label='euler forward')
# ax[1].plot(times, SHO_energy(phase_pts[:, 0], phase_pts[:, 1], k, m), label='euler forward')

# # Leapfrog(ish)
# phase_pts, times = integrate(phase_pt0=phase_pt0, accel_func=accel_func, step_func=euler_step2, t0=t0, T=T, N=N)
# ax[0].plot(times, phase_pts[:, 0], '-', label='leapfrog')
# ax[1].plot(times, phase_pts[:, 1], '-', label='leapfrog')
# ax[2].plot(times, SHO_energy(phase_pts[:, 0], phase_pts[:, 1], k, m), label='leapfrog')

# Velocity verlet
phase_pts, times = integrate(phase_pt0=phase_pt0, accel_func=accel_func, step_func=velocity_verlet_step, t0=t0, T=T, N=N)
ax[0].plot(times, phase_pts[:, 0], '-', label='verlet')
ax[1].plot(times, phase_pts[:, 1], '-', label='verlet')
ax[2].plot(times, SHO_energy(phase_pts[:, 0], phase_pts[:, 1], k, m), label='verlet')

# TRY: Use this analytic solution to check the limit where mass approaches zero.
# Analytic
phase_pts_analytic = DHO_analytic(phase_pt0=phase_pt0, k=k, m=m, b=b, ts=times)
ax[0].plot(times, phase_pts_analytic[:, 0], '-', label='analytic')
ax[1].plot(times, phase_pts_analytic[:, 1], '-', label='analytic')
ax[2].plot(times, SHO_energy(phase_pts_analytic[:, 0], phase_pts_analytic[:, 1], k=k, m=m), '-', label='analytic')

# # Exponential fit
# E0 = SHO_energy(phase_pt0[0], phase_pt0[1], k, m)
# ax[1].plot(times, E0*np.exp(-0.043 * times))

#ax[0].hlines(phase_pt0[0], 0, T)
#ax[0].hlines(-phase_pt0[0], 0, T)
ax[0].hlines(0, 0, T)
ax[1].hlines(0, 0, T)
ax[2].hlines(0, 0, T)

#ax[1].set_ylim(bottom=0)
ax[0].legend()
ax[1].legend()

# %% [markdown]
# ### TRY:
# Are the energies all monotonic? This might be hard to see by eye.
#
# Can you fit the exponential envelope in the energy curve?
# Try using dimensional analysis.

# %% [markdown]
# # Anharmonic oscillator

# %%
# Anharmonic Oscillator
def AHO_accel(x, v, k, m, a):
    return (-k * x - a * x**3) / m

def AHO_energy(x, v, k, m, a):
    # TRY: Implement this energy function.
    
    return 0.5 * m * v**2 + 0.5 * k * x**2 + 0.25 * a * x**4

# %%
# Explore a little - notice how the euler integration easily yields an overflow error.
k = 3.0
m = 7.0
a = 0.01

phase_pt0 = [3.0, 0.0]
t0 = 0
T = 20

N = 10**3

accel_func = lambda phase_pt: AHO_accel(x=phase_pt[0], v = phase_pt[1], k=k, m=m, a=a)

fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(16, 8))

# # Euler forward
# phase_pts, times = integrate(phase_pt0=phase_pt0, accel_func=accel_func, step_func=euler_step, t0=t0, T=T, N=N)
# ax[0].plot(times, phase_pts[:, 0], '-', label='euler forward')
# ax[1].plot(times, AHO_energy(phase_pts[:, 0], phase_pts[:, 1], k=k, m=m, a=a), label='euler forward')

# # Leapfrog(ish)
# phase_pts, times = integrate(phase_pt0=phase_pt0, accel_func=accel_func, step_func=euler_step2, t0=t0, T=T, N=N)
# ax[0].plot(times-dt/2, phase_pts[:, 0], '-', label='leapfrog')
# ax[1].plot(times, AHO_energy(phase_pts[:, 0], phase_pts[:, 1], k=k, m=m, a=a), label='leapfrog')

# Velocity verlet
phase_pts, times = integrate(phase_pt0=phase_pt0, accel_func=accel_func, step_func=velocity_verlet_step, t0=t0, T=T, N=N)
ax[0].plot(times, phase_pts[:, 0], '-', label='verlet')
ax[1].plot(times, AHO_energy(phase_pts[:, 0], phase_pts[:, 1], k=k, m=m, a=a), label='verlet')

ax[0].hlines(phase_pt0[0], 0, T)
ax[0].hlines(-phase_pt0[0], 0, T)
ax[0].hlines(0, 0, T)
ax[1].hlines(AHO_energy(phase_pt0[0], phase_pt0[1], k, m, a), 0, T, label='AHO analytic')

dt = times[1] - times[0]
omega = np.sqrt(k/m)
period = 2*np.pi / omega

for n in range(int(2*N*dt/period)):
    ax[0].vlines(period * (n/2 + 1/4), -1, 1, 'k', lw=0.5)
    
# ax[1].set_ylim(bottom=0)
ax[0].legend()
ax[1].legend()

# %% [markdown]
# # Anharmonicity vs period
#
# Numerically determine the relationship between anharmonicity and period.
#
# To do this programmatically, we need a way to estimate the period from the trajectory.
#
# ### TRY:
# Create a function that will estimate the period from the trajectory.
# Use this to plot period vs anharmonicity.

# %%
def estimate_period(xs, dt):
    """
    Here is one method we might use to estimate the period.
    I'm sure you can do better.
    """
    threshold = 0.1 
    xs = phase_pts[:, 0]
    np.abs(xs) < threshold
    inds = np.where(np.abs(xs) < threshold)
    inds = inds[0]
    
    return 2*np.max(np.diff(inds)) * dt
    
k = 3.0
m = 7.0

a_vals = np.linspace(0.001, 30, 100)

phase_pt0 = [3.0, 0.0]
t0 = 0
T = 20

N = 10**3

accel_func = lambda phase_pt: AHO_accel(x=phase_pt[0], v = phase_pt[1], k=k, m=m, a=a)

periods = []
for a in a_vals:
# Velocity verlet
    phase_pts, times = integrate(phase_pt0=phase_pt0, accel_func=accel_func, step_func=velocity_verlet_step, t0=t0, T=T, N=N)
    dt = times[1] - times[0]
    p = estimate_period(phase_pts[:, 0], dt)
    periods.append(p)
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(16, 8))
ax.plot(a_vals, periods, 'o-')
ax.set_ylim(bottom=0)
# Out:
# (0.0, 9.85)

# %% [markdown]
# ### TRY:
# Explain what is going on in the above computation especially where the anharmonicity becomes large.
# Construct a better estimator of the period.
# No need to get too fancy here.

# %% [markdown]
# # Kepler problem
# One planet around a stationary Sun.
# The main difference (code-wise) here is that there are *two* positions and *two* corresponding velocities.

# %%
M = 1.989 * 10**30 # mass of Sun [kg]
G = 6.673*10**(-11) # Newton's gravitational constant [m3 kg-1 s-2]

def kepler_accel(x, y, G, M):
    rad = (x**2 + y**2)**0.5
    a = G * M / rad**2
    ax = - a * x / rad
    ay = - a * y / rad
    return [ax, ay]

# %%
# Rewrite these integrators to accommodate 2D
def euler_step(phase_pt, accel_func, dt):
    a = accel_func(phase_pt)
    
    x = phase_pt[0] + phase_pt[2] * dt
    y = phase_pt[1] + phase_pt[3] * dt
    vx = phase_pt[2] + a[0] * dt
    vy = phase_pt[3] + a[1] * dt

    return [x, y, vx, vy]

def euler_step2(phase_pt, accel_func, dt):
    x = phase_pt[0] + phase_pt[2] * dt
    y = phase_pt[1] + phase_pt[3] * dt
    a = accel_func([x, y, phase_pt[2], phase_pt[3]])
    vx = phase_pt[2] + a[0] * dt
    vy = phase_pt[3] + a[1] * dt

    return [x, y, vx, vy]

def velocity_verlet_step(phase_pt, accel_func, dt):
    # TODO: rewrite for 2D
    x, v = phase_pt
    a = accel_func(phase_pt)
    vhalf = v + 0.5 * a * dt
    x1 = x + vhalf * dt
    a = accel_func([x1, v])
    v1 = vhalf + 0.5 * a * dt

    return [x1, v1]

# %%
def kinetic_energy(vx, vy, m):
    return 0.5 * m * (vx**2 + vy**2)

def gravitational_potential_energy(x, y, G, m1, m2):
    radius = (x**2 + y**2)**0.5
    return -G * m1 * m2 / radius

# %%
# TRY: Write a function to compute initial velocity given radius that would yield circular orbit.

def get_v0_for_circular_orbit():
    # Complete this function.
    return

# %%
m = 5.972 * 10**24 # mass of Earth [kg]
orbital_rad = 149.6 * 10**9 # orbital radius of Earth [m]

# Compare this value to the one from your function above
orbital_speed = 29.78 * 10**3 # orbital speed [m/s]

phase_pt0 = [orbital_rad, 0, 0, orbital_speed]
t0 = 0
years = 10
T = 60*60*24*365.25 * years

N = 10**3

accel_func = lambda phase_pt: kepler_accel(x=phase_pt[0], y = phase_pt[1], G=G, M=M)

fig = plt.figure(figsize=(8, 8))

# # Euler forward
# phase_pts, times = integrate(phase_pt0=phase_pt0, accel_func=accel_func, step_func=euler_step, t0=t0, T=T, N=N)
# plt.plot(phase_pts[:, 0], phase_pts[:, 1], '-', label='euler forward')

# Leapfrog(ish)
phase_pts, times = integrate(phase_pt0=phase_pt0, accel_func=accel_func, step_func=euler_step2, t0=t0, T=T, N=N)
plt.plot(phase_pts[:, 0], phase_pts[:, 1], '-', label='leapfrog')

# # Velocity verlet
# phase_pts, times = integrate(phase_pt0=phase_pt0, accel_func=accel_func, step_func=velocity_verlet_step, t0=t0, T=T, N=N)
# plt.plot(phase_pts[:, 0], phase_pts[:, 1], '-', label='verlet')

# plt.xlim([phase_pt0[0]*0.99, phase_pt0[0]*1.01])
# plt.ylim([-phase_pt0[0]*0.01, phase_pt0[0]*0.01])

plt.legend()


print("starting point = ", phase_pts[0, 0:2])
print("ending point = ", phase_pts[-1, 0:2])
print("difference = ", phase_pts[0, 0:2] - phase_pts[-1, 0:2])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-340240b8c980> in <module>
#      21
#      22 # Leapfrog(ish)
# ---> 23 phase_pts, times = integrate(phase_pt0=phase_pt0, accel_func=accel_func, step_func=euler_step2, t0=t0, T=T, N=N)
#      24 plt.plot(phase_pts[:, 0], phase_pts[:, 1], '-', label='leapfrog')
#      25
#
# <ipython-input-11-d945e6d915c7> in integrate(phase_pt0, accel_func, step_func, t0, T, N)
#      43
#      44     phase_pts = np.zeros((N + 1, 2))
# ---> 45     phase_pts[0, :] = phase_pt0
#      46
#      47     for ind in range(N):
#
# ValueError: cannot copy sequence with size 4 to array axis with dimension 2

# %% [markdown]
# ### TRY:
# Compare your solution with a circle.
# What is the maximum deviation?

# %% [markdown]
# ### TRY:
# Generate an orbit with twice the initial velocity.
# Generate an orbit with half the initial velocity.
# Plot all three together.
# Are the behaviors what you expect?

# %%
KE = kinetic_energy(vx=phase_pts[:,2], vy=phase_pts[:,3], m=m)
PE = gravitational_potential_energy(phase_pts[:,0], phase_pts[:,1], G=G, m1=M, m2=m)
plt.plot(times, KE, label='KE')
plt.plot(times, PE, label='PE')
plt.plot(times, KE + PE, label='E')

# plt.ylim(bottom=0)
plt.legend()

# %% [markdown]
# ### TRY:
# Analyze the conservation / stability of angular momentum using these integrators.

# %%
def angular_momentum():
    # Complete this function.
    return

# %% [markdown]
# ### QUIZ:
# - Why is the total energy negative?

# %% [markdown]
# ### CHALLENGE:
# -
